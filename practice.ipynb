# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\nisha\Desktop\even_assign\data_science_task_dataset.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
x1 = np.linspace(0,5,10)
y1 = x1**2
plt.plot(x1,y1)
plt.title("Chart")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
plt.subplot(1,2,1)
plt.plot(x1,y1,'r')
plt.subplot(1,2,2)
plt.plot(x1,y1,'b')

# %%
fig1 = plt.figure(figsize=(12,8)) # defining the fig size 
axes1 = fig1.add_axes([1,1,1,1])
axes1.set_xlabel("d")
axes1.set_ylabel("f")
axes1.set_title('f')
axes1.plot(x1,y1, label = 'c/x2')# the label hers is for the legend 
axes1.plot(y1,x1, label = 'c/w')
axes1.legend(loc = 0)# fihures out the best location for your legend

# %%
fig3 = plt.figure(figsize=(12,8))
axes3 = fig3.add_axes([0.1,0.1,0.9,0.9])
axes3.plot(x1,y1,color = 'navy', alpha = 0.75 , lw = 2 , ls = '-.', marker = 'o',markersize = '7',
           markerfacecolor = 'y')


axes3.grid(True,color = '0.6')
axes3.set_facecolor('#FAEBD7')

# %%
df = data.iloc[:50][['plan_months','payment_amount']]

# %%
df.sort_values(by= 'plan_months')

# %%
arr = df.values
x2 = arr[:,0]
y2 = arr[:,1]
fig4 = plt.figure(figsize=(12,8))
axes4 = fig4.add_axes([0,0,1,1])
axes4.plot(x2,y2,color='r',)
# axes4.annotate("good_thing", xy = (34,22), xytext = (60,520)) # to annotate and write message at a point at the xy coordinate and the text coordinate 
# axes4.text(0,23, r'$\alpha$' ) to add raw text at some coordinate

# %%
# histograms 

arr1 = np.random.randint(1,7,7000)
arr2 = np.random.randint(1,7,7000)
arr3 = arr1 + arr2

# %%
plt.hist(arr3,bins = 11, density = True , stacked = True) # desnity returns frequecny o each of the bins
# Out:
# (array([0.03221429, 0.06097143, 0.09397143, 0.11911429, 0.154     ,
#         0.18495714, 0.1595    , 0.1188    , 0.08281429, 0.0638    ,
#         0.02985714]),
#  array([ 2.        ,  2.90909091,  3.81818182,  4.72727273,  5.63636364,
#          6.54545455,  7.45454545,  8.36363636,  9.27272727, 10.18181818,
#         11.09090909, 12.        ]),
#  <BarContainer object of 11 artists>)

# %%
# bar charts 


sp = np.arange(5)

# %%
m_eng = (76,23,53,23,45)
f_eng = (33,32,43,64,23)

# %%
plt.bar(sp , m_eng, width=0.45, label= 'efds')
plt.xticks(sp +0.45/2 , ('ad','ee','df','daa','ww'))
plt.bar(sp+0.45 , f_eng, width=0.45, label= 'efds')
# Out:
# <BarContainer object of 5 artists>

# %%
types = ['kinf','dff','fssv','fsfs']
m_tech = np.array([23,21,44,53])
f_tech = np.array([34,22,34,23])
index = [x for x, _ in enumerate(types)]
plt.bar(index , m_tech, width=0.45, bottom= f_tech )
plt.bar(index , f_tech , width = 0.45 )
# Out:
# <BarContainer object of 4 artists>
